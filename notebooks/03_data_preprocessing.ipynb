# %% [markdown]
# # Challenge # 3
# Task: Perform data cleaning
#
# Data src: [house-prices-advanced-regression-techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
#
#
# Github src for downloading raw data: [github.com/moyphilip](https://raw.githubusercontent.com/moyphilip/Ames-Housing/master/train.csv)
#
# Google Colab for this notebook: [link](https://colab.research.google.com/drive/1BDv0x-mYqTJAHfS2XttTGvcffTfrtcRW?usp=sharing)
#
# By: Christian Vadillo

# %% [markdown]
# Loading libraries

# %%
import os
import pandas as pd
import seaborn as sns
import warnings
from pathlib import Path

warnings.filterwarnings('ignore')
pd.set_option('display.precision', 2)

# %% [markdown]
# # Loading data

# %%
wget 'https://raw.githubusercontent.com/moyphilip/Ames-Housing/master/train.csv'
# Out:
#   File "<ipython-input-5-2162391cccbc>", line 1
#     wget 'https://raw.githubusercontent.com/moyphilip/Ames-Housing/master/train.csv'
#          ^
# SyntaxError: invalid syntax

# %%
cwd = os.getcwd()
print(cwd)
PATH = Path(cwd)
# Out:
# D:\PYTHON_PROJECTS\ML\SaturdaysAI\saturdaysai\notebooks

# %% [markdown]
# ## 1. Leer los datos del CSV creando un data frame de pandas

# %%
df = pd.read_csv(PATH/'train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## 2.  ¿Cuántas columnas hay en el data frame?

# %%
print(f'Theare are {len(df.columns)} columns')
# Out:
# Theare are 81 columns

# %% [markdown]
# ## 3. Calcula los descriptores estadísticos básicos para las columnas numéricas

# %%
df.describe().T
# Out:
#                 count       mean       std  ...       50%        75%       max
# Id             1460.0     730.50    421.61  ...     730.5    1095.25    1460.0
# MSSubClass     1460.0      56.90     42.30  ...      50.0      70.00     190.0
# LotFrontage    1201.0      70.05     24.28  ...      69.0      80.00     313.0
# LotArea        1460.0   10516.83   9981.26  ...    9478.5   11601.50  215245.0
# OverallQual    1460.0       6.10      1.38  ...       6.0       7.00      10.0
# OverallCond    1460.0       5.58      1.11  ...       5.0       6.00       9.0
# YearBuilt      1460.0    1971.27     30.20  ...    1973.0    2000.00    2010.0
# YearRemodAdd   1460.0    1984.87     20.65  ...    1994.0    2004.00    2010.0
# MasVnrArea     1452.0     103.69    181.07  ...       0.0     166.00    1600.0
# BsmtFinSF1     1460.0     443.64    456.10  ...     383.5     712.25    5644.0
# BsmtFinSF2     1460.0      46.55    161.32  ...       0.0       0.00    1474.0
# ...

# %% [markdown]
# ## 4. ¿Cuántas columnas numéricas y cuántas columnas categóricas hay?

# %%
# df = df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.convert_dtypes().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   Int64
#  1   MSSubClass     1460 non-null   Int64
#  2   MSZoning       1460 non-null   string
#  3   LotFrontage    1201 non-null   Int64
#  4   LotArea        1460 non-null   Int64
#  5   Street         1460 non-null   string
#  6   Alley          91 non-null     string
#  7   LotShape       1460 non-null   string
#  8   LandContour    1460 non-null   string
#  9   Utilities      1460 non-null   string
#  10  LotConfig      1460 non-null   string
#  11  LandSlope      1460 non-null   string
#  12  Neighborhood   1460 non-null   string
#  13  Condition1     1460 non-null   string
#  14  Condition2     1460 non-null   string
#  15  BldgType       1460 non-null   string
#  16  HouseStyle     1460 non-null   string
# ...

# %%
# df = df.convert_dtypes()

# %%
numeric_cols = df.select_dtypes(include='number').columns
numeric_cols
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
cat_cols = df.select_dtypes(exclude='number').columns
cat_cols
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
print(f'Total numeric columns:', len(numeric_cols))
print(f'Total categorical columns: ', len(cat_cols))
# Out:
# Total numeric columns: 38
# Total categorical columns:  43

# %% [markdown]
# ## 5. ¿Cuáles variables tienen más del 50% de valores NaN?

# %%
null_cols = df.isnull().sum()/len(df) * 100

# %%
null_cols = df.isnull().sum()/len(df) * 100
null_cols[null_cols > 50.].sort_values(ascending=False)
# Out:
# PoolQC         99.52
# MiscFeature    96.30
# Alley          93.77
# Fence          80.75
# dtype: float64

# %% [markdown]
# ## 6. ¿Cuántos valores faltantes tiene cada una de las variables categóricas?

# %%
# From question 4: using cat_cols as a filter
null_cols[cat_cols].sort_values(ascending=False)
# Out:
# PoolQC           99.52
# MiscFeature      96.30
# Alley            93.77
# Fence            80.75
# FireplaceQu      47.26
# GarageCond        5.55
# GarageQual        5.55
# GarageFinish      5.55
# GarageType        5.55
# BsmtFinType2      2.60
# BsmtExposure      2.60
# BsmtFinType1      2.53
# BsmtQual          2.53
# BsmtCond          2.53
# MasVnrType        0.55
# Electrical        0.07
# Condition2        0.00
# Condition1        0.00
# Neighborhood      0.00
# LandSlope         0.00
# BldgType          0.00
# LandContour       0.00
# LotConfig         0.00
# Utilities         0.00
# RoofStyle         0.00
# LotShape          0.00
# Street            0.00
# HouseStyle        0.00
# SaleCondition     0.00
# RoofMatl          0.00
# Exterior1st       0.00
# Exterior2nd       0.00
# ExterQual         0.00
# ExterCond         0.00
# Foundation        0.00
# SaleType          0.00
# Heating           0.00
# HeatingQC         0.00
# CentralAir        0.00
# KitchenQual       0.00
# ...

# %%
ax = sns.heatmap(df[cat_cols].isnull().T,
                 xticklabels=False,
                 cbar=False, cmap='viridis_r')
ax.set_title('Missing values for categorical columns');

# %% [markdown]
# #7. ¿Cuántos valores faltantes tiene cada una de las variables numéricas?

# %%
# From question 4: using numeric_cols as a filter
null_cols[numeric_cols].sort_values(ascending=False)/100 * len(df)
# Out:
# LotFrontage      259.0
# GarageYrBlt       81.0
# MasVnrArea         8.0
# BsmtFinSF1         0.0
# LowQualFinSF       0.0
# 2ndFlrSF           0.0
# 1stFlrSF           0.0
# TotalBsmtSF        0.0
# BsmtUnfSF          0.0
# BsmtFinSF2         0.0
# SalePrice          0.0
# BsmtFullBath       0.0
# YearRemodAdd       0.0
# YearBuilt          0.0
# OverallCond        0.0
# OverallQual        0.0
# LotArea            0.0
# MSSubClass         0.0
# GrLivArea          0.0
# BsmtHalfBath       0.0
# YrSold             0.0
# FullBath           0.0
# MoSold             0.0
# MiscVal            0.0
# PoolArea           0.0
# ScreenPorch        0.0
# 3SsnPorch          0.0
# EnclosedPorch      0.0
# OpenPorchSF        0.0
# WoodDeckSF         0.0
# GarageArea         0.0
# GarageCars         0.0
# Fireplaces         0.0
# TotRmsAbvGrd       0.0
# KitchenAbvGr       0.0
# BedroomAbvGr       0.0
# HalfBath           0.0
# Id                 0.0
# dtype: float64

# %%
df[numeric_cols].isnull().sum().sort_values(ascending=False)
# Out:
# LotFrontage      259
# GarageYrBlt       81
# MasVnrArea         8
# BsmtFinSF1         0
# LowQualFinSF       0
# 2ndFlrSF           0
# 1stFlrSF           0
# TotalBsmtSF        0
# BsmtUnfSF          0
# BsmtFinSF2         0
# SalePrice          0
# BsmtFullBath       0
# YearRemodAdd       0
# YearBuilt          0
# OverallCond        0
# OverallQual        0
# LotArea            0
# MSSubClass         0
# GrLivArea          0
# BsmtHalfBath       0
# YrSold             0
# FullBath           0
# MoSold             0
# MiscVal            0
# PoolArea           0
# ScreenPorch        0
# 3SsnPorch          0
# EnclosedPorch      0
# OpenPorchSF        0
# WoodDeckSF         0
# GarageArea         0
# GarageCars         0
# Fireplaces         0
# TotRmsAbvGrd       0
# KitchenAbvGr       0
# BedroomAbvGr       0
# HalfBath           0
# Id                 0
# dtype: int64

# %%
ax = sns.heatmap(df[numeric_cols].isnull().T, 
                 xticklabels=False,
                 cbar=False, cmap='viridis_r')
ax.set_title('Missing values for numerical columns');

# %% [markdown]
# ## 8. Sustituye los valores faltantes de la columna YrSold con la media de esa columna

# %%
print(df['YrSold'].value_counts(dropna=False))
print('\nThere are not missing values in YrSold column')
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64
#
# There are not missing values in YrSold column

# %% [markdown]
# ## 9. Sustituye los valores faltantes de la columna LotFrontage con la mediana de esa columna

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(), inplace=True)
df['LotFrontage'].value_counts(dropna=False)
# Out:
# 69.0     270
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 33.0       1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 110, dtype: int64

# %% [markdown]
# ## 10. Codifica la columna SaleCondition utilizando One-Hot-Encoding

# %%
df['SaleCondition'].value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
df = pd.get_dummies(data=df,
                    columns=['SaleCondition'],
                    drop_first=True
                    )
df.iloc[:, -6:]
# Out:
#       SalePrice  ...  SaleCondition_Partial
# 0        208500  ...                      0
# 1        181500  ...                      0
# 2        223500  ...                      0
# 3        140000  ...                      0
# 4        250000  ...                      0
# ...         ...  ...                    ...
# 1455     175000  ...                      0
# 1456     210000  ...                      0
# 1457     266500  ...                      0
# 1458     142125  ...                      0
# 1459     147500  ...                      0
#
# [1460 rows x 6 columns]

# %% [markdown]
# ## 11. Crea una columna TotalBath a partir de la suma de baños completos e incompletos (debes descubrir cuales columnas sumar). Hint: los cantidad de baños incompletos debe multiplicarse por 0.5 antes de sumarse.
#
# ```
# BsmtFullBath: Basement full bathrooms
# BsmtHalfBath: Basement half bathrooms
# FullBath: Full bathrooms above grade
# HalfBath: Half baths above grade
# ```

# %%
df.eval(
    'TotalBath = BsmtFullBath + 0.5 * BsmtHalfBath + FullBath + 0.5 * HalfBath',
    inplace=True
    )

df['TotalBath'].value_counts()
# Out:
# 2.0    456
# 2.5    295
# 1.0    228
# 3.0    186
# 3.5    144
# 1.5    129
# 4.0     13
# 4.5      7
# 5.0      1
# 6.0      1
# Name: TotalBath, dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass  ... SaleCondition_Partial  TotalBath
# 0   1          60  ...                     0        3.5
# 1   2          20  ...                     0        2.5
# 2   3          60  ...                     0        3.5
# 3   4          70  ...                     0        2.0
# 4   5          60  ...                     0        3.5
#
# [5 rows x 86 columns]

# %% [markdown]
# ## 12. Grafica la distribución de la columna LotArea

# %%
ax = sns.distplot(df['LotArea'], hist=False)
ax.set_xscale('log')

# %% [markdown]
# ## 13. Grafica la distribución de la columna SalePrice

# %%
df['SalePrice'].plot(kind='hist',)

# %%
df['SalePrice'].plot.kde()

# %%
ax = sns.distplot(df['SalePrice'], hist=False)
ax.set_xscale('log')

# %% [markdown]
# ## 14. Elimina la columna Id del dataset.

# %%
df.drop(['LotArea', 'Street'], axis=1, inplace=True)
df.head()
# Out:
#    Id  MSSubClass  ... SaleCondition_Partial  TotalBath
# 0   1          60  ...                     0        3.5
# 1   2          20  ...                     0        2.5
# 2   3          60  ...                     0        3.5
# 3   4          70  ...                     0        2.0
# 4   5          60  ...                     0        3.5
#
# [5 rows x 84 columns]

# %%
del df['Id']

# %%
df.head()
# Out:
#    MSSubClass MSZoning  ...  SaleCondition_Partial TotalBath
# 0          60       RL  ...                      0       3.5
# 1          20       RL  ...                      0       2.5
# 2          60       RL  ...                      0       3.5
# 3          70       RL  ...                      0       2.0
# 4          60       RL  ...                      0       3.5
#
# [5 rows x 83 columns]
